# %%
# Basic usage
from batch_pharmacophore_analyzer import BatchPharmacophoreAnalyzer
# Process your own SDF file
analyzer = BatchPharmacophoreAnalyzer()
molecules_data = analyzer.process_sdf_file(
    "compounds.sdf",
    output_dir="results",
    max_molecules=100,  # Process first 100 (None for all)
    generate_images=True,
    generate_3d=True #Set False for faster processing
)
# Out:
# ...
# BATCH PHARMACOPHORE ANALYZER
# ...
# [✓] Batch analyzer initialized
#
# Processing SDF file: compounds.sdf
# ------------------------------------------------------------
#
# Processing 1: ZINC000000407042
# ----------------------------------------
#   Features found: 14
#     Donor: 2
#     Acceptor: 3
#     NegIonizable: 1
#     Aromatic: 1
#     Hydrophobe: 6
#     LumpedHydrophobe: 1
# Creating 3D interactive pharmacophore...
#   ✓ Saved: results/molecules/ZINC000000407042/ZINC000000407042_3d.html
#
# Processing 2: ZINC000238647610
# ----------------------------------------
#   Features found: 13
#     Donor: 2
#     Acceptor: 4
#     NegIonizable: 1
#     Aromatic: 1
#     Hydrophobe: 4
#     LumpedHydrophobe: 1
# Creating 3D interactive pharmacophore...
#   ✓ Saved: results/molecules/ZINC000238647610/ZINC000238647610_3d.html
#
# Processing 3: ZINC000005459729
# ----------------------------------------
#   Features found: 8
#     Donor: 2
#     Acceptor: 2
#     NegIonizable: 1
# ...

# %%
# 1. Full analysis with both 2D and 3D
analyzer.process_sdf_file(
    "compounds.sdf",
    output_dir="full_analysis",
    generate_images=True,
    generate_3d=True
)

# %%
# 4. Only 2D visualizations (no 3D HTML)
analyzer.process_sdf_file(
    "compounds.sdf",
    output_dir="2d_only",
    generate_images=True,
    generate_3d=False
)

# %%
# 3. Only 3D visualizations (no 2D images)
analyzer.process_sdf_file(
    "compounds.sdf",
    output_dir="3d_only",
    generate_images=False,
    generate_3d=True
)

# %%
# 2. Quick CSV-only for large libraries (fastest)
analyzer.process_sdf_file(
    "compounds.sdf",
    output_dir="quick_analysis",
    generate_images=False,
    generate_3d=False
)
